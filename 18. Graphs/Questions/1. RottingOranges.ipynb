# %% [markdown]
# ### Leetcode - 994 :
# (Medium)
# You are given an m x n grid where each cell can have one of three values:
#
# - 0 representing an empty cell,
# - 1 representing a fresh orange, or
# - 2 representing a rotten orange.
# - Every minute, any fresh orange that is 4-directionally adjacent to a rotten orange becomes rotten.
#
# Return the minimum number of minutes that must elapse until no cell has a fresh orange. If this is impossible, return -1.

# %% [markdown]
# ### Idea
#
# 1. We first count the number of fresh fruits and store it in a variable and store coordinate of rotten fruits in a queue.
# 2. We run a loop until rotten fruit queue become empty or fresh fruit become 0.
# 3. We first pop the first rotten fruit containing its coordiante (i, j). It will rot the fruit which are at top, bottom, right and left which are coordiantes
#     - top : (i-1, j). So whatever i and j is simply do (-1, 0).
#     - bottom : (i+1, j). So whatever i and j is simply do (1, 0).
#     - left : (i, j-1). So whatever i and j is simply do (0, -1).
#     - right : (i, j+1). So whatever i and j is simply do (0, 1).
# 4. We have to put a check to see if we go out of bound i.e, for top if new_i become -1; for bottom if new_i become more than given grid's row length; for left if new_j become -1; for right if new_j become more than given grid's column length.
# 5. We also put a check for if the new coordiante has no fruit than simply move on to next rotten coordinate.
# 6. If the new coordinate has fresh fruit: decrease fresh fruit count, add coordinate of newly rotten fruit in queue.

# %%
from collections import deque
from copy import deepcopy

def orangesRotting(grid):
    rows = len(grid)
    cols = len(grid[0])
    grid_copy = deepcopy(grid)
    
    fresh_cnt = 0
    queue = deque()
    
    for r in range(rows):
        for c in range(cols):
            if grid_copy[r][c] == 2:
                queue.append((r,c))
            elif grid_copy[r][c] == 1:
                fresh_cnt += 1
    minutes = 0
    while len(queue) != 0 and fresh_cnt > 0:
        minutes += 1
        total_rotten = len(queue)
        for _ in range(total_rotten):
            i,j = queue.popleft()
            for dx, dy in [(1,0),(0,1),(0,-1),(-1,0)]:
                new_i, new_j = i + dx, j + dy
                if new_i < 0 or new_i == rows or new_j < 0 or new_j == cols:
                    continue
                if grid_copy[new_i][new_j] == 0 or grid_copy[new_i][new_j] == 2:
                    continue
                fresh_cnt -= 1
                grid_copy[new_i][new_j] = 2
                queue.append((new_i,new_j))
    if fresh_cnt > 0:
        return -1
    return minutes

print(orangesRotting([[2,1,1],[0,1,1],[1,0,1]]))
# Out:
# -1
